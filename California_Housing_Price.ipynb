# %%
# import library yang dibutuhkan
import pandas as pd

# %%
# menghubungkan google colab dengan google drive
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# load file csv
data = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/California_Housing_Price_Story_Telling/california_housing_test.csv')

# %%
# menampilkan 10 data teratas
data.head(10)

# %%
# menampilkan 10 data terbawah
data.tail(10)

# %%
# melihat ukuran data
data.shape

# %%
# cek missing value
data.info()

# %%
# data set ini tidak memiliki missing value
